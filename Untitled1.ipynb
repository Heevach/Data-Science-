# %% [markdown]
# KNN Algirothm

# %% [markdown]
# Calculating neighbor distance:
#
# - Euclidean method
#
# - Manhattan method
#
# - Minkowski method
#
# - Hamming method

# %% [markdown]
# با توجه به اطلاعات جدول، فردی با قد ۱۷۰ سانتی متر و وزن ۵۷ در کدام دسته قرار می گیرد؟

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
data=np.array([[167,51,0],
[182,62,1],
[176,69,1],
[173,64,1],
[172,65,1],
[174,56,0],
[169,58,1],
[173,57,1],
[170,55,1]])
x=data[:,:-1]
y=data[:,-1]
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
error=[]
for i in range(1,7):
    model=KNeighborsClassifier(n_neighbors=i)
    model.fit(xtrain,ytrain)
    ypred=model.predict(xtest)
    error.append(np.mean(ypred!=ytest))
    
import matplotlib.pyplot as plt
plt.plot(range(1,7),error)
plt.xlabel("n_neighbors")
plt.ylabel("error")
plt.show()
