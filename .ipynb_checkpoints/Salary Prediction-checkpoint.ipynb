# %% [markdown]
# در جدول حقوق براساس سابقه کاری قرار گرفته است. با توجه با این اطلاعاتی
# حقوق فردی با ده سال سابقه کاری چقدر است؟

# %%
#data
import pandas as pd
data=pd.read_excel("salary.xlsx")
x = data.iloc[:, :-1].values
y = data.iloc[:, 1].values

# %%
#model and prediction
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(x, y)
x_test=x
y_test=y
y_pred = model.predict(x_test)

# %%
#evaluation
from sklearn.metrics import r2_score
print("r2=",r2_score(y_test,y_pred))
# Out:
# r2= 0.9569566641435086

# %%
#plot
import matplotlib.pyplot as plt
plt.scatter(x,y,label="data")
plt.plot(x_test,y_pred,label="predict")
plt.legend()
plt.show()

# %%
#predicting
y_pred = model.predict([[10]])
y_pred
# Out:
# array([120291.82341322])
